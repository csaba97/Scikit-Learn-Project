# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
pd.options.mode.chained_assignment = None
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import KFold
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score

# %%
df = pd.read_csv('note.csv')
df = df.reset_index()

# %%
Y = df[['rezultatul final']]  

X = pd.DataFrame()

fails = []

# for ind, a in enumerate(df['media la admitere']):
#     if df['nota la limba romana'][ind] < 5 or df['nota la matematica'][ind] < 5 or df['optional8 nota'][ind] < 5:
#         fails.append(0)
#     else:
#         fails.append(1)



X = df[['media la admitere']]
#X['fails'] = fails

# def grade(g):
#     round(g, 1)

# X['media la admitere'] = X['media la admitere'].apply(grade)

# for ind, a in enumerate(X['media la admitere']):
#     X['media la admitere'][ind] = round(X['media la admitere'][ind], 0)

# %%
X.shape
# Out:
# (13190, 1)

# %%
for i,c in enumerate(X.columns):
        if X[c].dtype == 'object':
            lbl = LabelEncoder()
            lbl.fit(list(X[c].values))
            X[c] = lbl.transform(list(X[c].values)) 

for i,c in enumerate(Y.columns):
    if Y[c].dtype == 'object':
        lbl = LabelEncoder()
        lbl.fit(list(Y[c].values))
        Y[c] = lbl.transform(list(Y[c].values)) 
Y.head()
# Out:
#     rezultatul final
# 8                  1
# 9                  1
# 25                 1
# 26                 1
# 27                 1

# %%
Y_train.groupby(Y_train['rezultatul final']).size().plot(kind='bar')

# %%
Y_test.groupby(Y_test['rezultatul final']).size().plot(kind='bar')

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.20, random_state = 40) #same seed to compare results

model = RandomForestClassifier(n_jobs=-1, n_estimators=100)
model.fit(X_train, Y_train)
Y_pred = model.predict(X_test)
print accuracy_score(Y_pred, Y_test)

print confusion_matrix(Y_test, Y_pred)

print precision_score(Y_test, Y_pred, average='macro') 
print recall_score(Y_test, Y_pred, average='macro')
# Out:
# c:\python27\lib\site-packages\ipykernel_launcher.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   after removing the cwd from sys.path.
# 0.7911296436694466
# [[1140  210]
#  [ 341  947]]
# 0.7941231397179018
# 0.7898464458247068

# %%
feature_importances = pd.DataFrame(model.feature_importances_,
                                   index = X.columns,
                                    columns=['importance']).sort_values('importance',
                                                                        ascending=False)

feature_importances
# Out:
#                    importance
# media la admitere         1.0

# %%
res = pd.DataFrame()

# %%
res['real'] = Y_test['rezultatul final']
res['pred'] = Y_pred
res
# Out:
#        real  pred
# 7858      0     1
# 7663      1     1
# 10016     1     1
# 7881      0     0
# 7553      0     0
# 8752      1     1
# 3028      1     1
# 9858      0     0
# 6062      0     0
# 7872      1     1
# 1592      1     1
# 7426      0     0
# 7102      0     0
# 2871      1     1
# 7624      1     0
# 9636      1     1
# 7672      0     0
# 2354      1     1
# 9331      0     1
# 4172      1     1
# 3300      1     1
# 3821      1     1
# 5349      0     0
# 4888      0     0
# 2224      0     0
# 3514      1     1
# 5516      1     1
# 1731      1     1
# 5748      1     1
# 5239      1     1
# ...     ...   ...
# 5536      1     1
# 7459      1     1
# 6869      1     1
# 2947      1     1
# 10099     1     1
# 5252      0     1
# 7027      0     0
# 3808      1     1
# 6192      1     1
# 7560      1     1
# 3547      0     0
# 2686      1     1
# 1737      1     1
# 2627      1     1
# 3392      0     0
# 5079      1     1
# 3409      1     1
# 6756      1     1
# 2585      0     0
# 2786      0     0
# 184       1     1
# 4004      0     0
# 6480      1     1
# 430       1     1
# 1216      0     1
# 7137      1     1
# 5968      1     1
# 1556      0     0
# 5528      1     1
# 2315      0     1
#
# [2023 rows x 2 columns]

# %%
#resample






print len(Y[Y['rezultatul final']==0])
print len(Y[Y['rezultatul final']==1])
# Out:
# 3517
# 6595

# %%
#resample

from sklearn.utils import resample

# Separate majority and minority classes
df_majority = df[df['rezultatul final']=='Reusit']
df_minority = df[df['rezultatul final']=='Respins']

# %%
# Upsample minority class
df_minority_upsampled = resample(df_minority, 
                                 replace=True,     # sample with replacement
                                 n_samples=6595,    # to match majority class
                                 random_state=123) # reproducible results
 
# Combine majority class with upsampled minority class
df = pd.concat([df_majority, df_minority_upsampled])
 
# Display new class counts
df['rezultatul final'].value_counts()
# Out:
# Respins    6595
# Reusit     6595
# Name: rezultatul final, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13190 entries, 8 to 6517
# Data columns (total 42 columns):
# index                            13190 non-null int64
# nume                             13190 non-null object
# judet8                           13190 non-null object
# scoala                           13190 non-null object
# media la admitere                13190 non-null float64
# media teze nationale             13190 non-null float64
# media de absolvire               13190 non-null float64
# nota la limba romana             13190 non-null float64
# nota la matematica               13190 non-null float64
# optional8                        13190 non-null object
# optional8 nota                   13190 non-null float64
# limba materna8                   13190 non-null object
# limba materna8 nota              13190 non-null object
# pozitia in ierarhie pe judet     13190 non-null int64
# pozitia in ierarhie pe tara      13190 non-null int64
# unitatea de invatamant           13190 non-null object
# judetul                          13190 non-null object
# promotie anterioara              13190 non-null object
# forma invatamant                 13190 non-null object
# specializare                     13190 non-null object
# romana oral                      13190 non-null object
# romana nota                      13190 non-null float64
# romana contestatie               1625 non-null float64
# romana final                     13190 non-null float64
# limba materna                    1406 non-null object
# materna oral                     1406 non-null object
# materna nota                     1406 non-null float64
# materna contestatie              93 non-null float64
# materna final                    1406 non-null float64
# limba moderna                    13190 non-null object
# limba moderna nota               12131 non-null object
# disciplina profil                13190 non-null object
# disciplina profil nota           13190 non-null float64
# disciplina profil contestatie    1972 non-null float64
# disciplina profil final          13190 non-null float64
# optional                         13190 non-null object
# optional nota                    13190 non-null float64
# optional contestatie             1183 non-null float64
# optional final                   13190 non-null float64
# competente digitale              13190 non-null object
# media                            13190 non-null float64
# rezultatul final                 13190 non-null object
# dtypes: float64(19), int64(3), object(20)
# memory usage: 4.6+ MB

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, df_upsampled, test_size=0.20, random_state = 40) #same seed to compare results

model = RandomForestClassifier(n_jobs=-1, n_estimators=100)
model.fit(X_train, Y_train)
Y_pred = model.predict(X_test)
print accuracy_score(Y_pred, Y_test)

print confusion_matrix(Y_test, Y_pred)

print precision_score(Y_test, Y_pred, average='macro') 
print recall_score(Y_test, Y_pred, average='macro')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-188-3f1dd24313ad> in <module>()
# ----> 1 X_train, X_test, Y_train, Y_test = train_test_split(X, df_upsampled, test_size=0.20, random_state = 40) #same seed to compare results
#       2
#       3 model = RandomForestClassifier(n_jobs=-1, n_estimators=100)
#       4 model.fit(X_train, Y_train)
#       5 Y_pred = model.predict(X_test)
#
# c:\python27\lib\site-packages\sklearn\model_selection\_split.pyc in train_test_split(*arrays, **options)
#    2182         test_size = 0.25
#    2183
# -> 2184     arrays = indexable(*arrays)
#    2185
#    2186     if shuffle is False:
#
# c:\python27\lib\site-packages\sklearn\utils\validation.pyc in indexable(*iterables)
#     258         else:
#     259             result.append(np.array(X))
# --> 260     check_consistent_length(*result)
#     261     return result
#     262
#
# c:\python27\lib\site-packages\sklearn\utils\validation.pyc in check_consistent_length(*arrays)
#     233     if len(uniques) > 1:
#     234         raise ValueError("Found input variables with inconsistent numbers of"
# --> 235                          " samples: %r" % [int(l) for l in lengths])
#     236
#     237
#
# ValueError: Found input variables with inconsistent numbers of samples: [10112, 13190]
