# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.metrics import mean_squared_error
from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv('eval.csv')

# %%
df2 = pd.read_csv('bac.csv')

# %%
df2.keys()
# Out:
# Index([u'nume', u'pozitia in ierarhie pe judet',
#        u'pozitia in ierarhie pe tara', u'unitatea de invatamant', u'judetul',
#        u'promotie anterioara', u'forma invatamant', u'specializare',
#        u'romana oral', u'romana nota', u'romana contestatie', u'romana final',
#        u'limba materna', u'materna oral', u'materna nota',
#        u'materna contestatie', u'materna final', u'limba moderna',
#        u'limba moderna nota', u'disciplina profil', u'disciplina profil nota',
#        u'disciplina profil contestatie', u'disciplina profil final',
#        u'optional', u'optional nota', u'optional contestatie',
#        u'optional final', u'competente digitale', u'media',
#        u'rezultatul final'],
#       dtype='object')

# %%
df.keys()
# Out:
# Index([u'Unnamed: 0', u'nume', u'judet', u'scoala', u'media la admitere',
#        u'media teze nationale', u'media de absolvire',
#        u' nota la limba romana', u'nota la matematica', u'optional8',
#        u'optional8 nota', u'limba materna8', u'limba materna8 nota '],
#       dtype='object')

# %%
df.shape
# Out:
# (32358, 13)

# %%
df.nume = df.nume.str.lower()
df2.nume = df2.nume.str.lower()

# %%
df.nume = df.nume.str.strip()
df2.nume = df2.nume.str.strip()

# %%
s1 = pd.merge(df, df2, how='inner', on=['nume'])

# %%
s1
# Out:
#        Unnamed: 0                                  nume  judet  \
# 0             1.0                      cireap p. florin  BIHOR
# 1             2.0                 gabor i. ionut darius  BIHOR
# 2             3.0               bogan s. sebastian doru  BIHOR
# 3             4.0                 apati m. mihai bogdan  BIHOR
# 4             5.0              filip g. flaviu georgian  BIHOR
# 5             6.0                  dan m. ovidiu vasile  BIHOR
# 6             7.0                        korch s. iozef  BIHOR
# 7             8.0                hora i. cristian ionut  BIHOR
# 8             9.0               jude a. corneliu daniel  BIHOR
# 9            10.0                groza u. raul cristian  BIHOR
# 10           12.0             petroian v. florin adrian  BIHOR
# 11           13.0                bogdan i. remus daniel  BIHOR
# 12           14.0               bonchis a. costel tudor  BIHOR
# 13           15.0               lungu p. nicusor marius  BIHOR
# 14           16.0             gligor l. florin cristian  BIHOR
# 15           17.0                popa m. mihaela alicia  BIHOR
# 16           19.0           breanc t. marius constantin  BIHOR
# 17           20.0             semeni v. octavian vasile  BIHOR
# 18           22.0                  toma d. daniel ionut  BIHOR
# 19           23.0                 iagar f. serban petru  BIHOR
# 20           24.0                        laza g. george  BIHOR
# 21           25.0              tau d. adrian dan florin  BIHOR
# 22           26.0                 toma f. paul cristian  BIHOR
# 23           27.0           bunicau t. minodora claudia  BIHOR
# 24           28.0           farcut pocioian i. anamaria  BIHOR
# 25            7.0              solosi f. denisa andreea  BIHOR
# 26           10.0               salajan c. ionut cornel  BIHOR
# 27           11.0               dragan t. teodor teofil  BIHOR
# 28           13.0                   fulop i. raul ionut  BIHOR
# 29           14.0                   dod i. ionela maria  BIHOR
# ...           ...                                   ...    ...
# 10636         1.0                       vomir m. marian   CLUJ
# 10637         2.0                 zahan d. raul dumitru   CLUJ
# 10638         3.0                  tritean a. alexandra   CLUJ
# 10639         4.0                      giurgiu t. calin   CLUJ
# 10640         5.0               nistor d. dorian-traian   CLUJ
# 10641         8.0                palacean e. gelu-ionut   CLUJ
# 10642         9.0                     stefan z. norbert   CLUJ
# 10643        11.0                lacan t. maria-adriana   CLUJ
# 10644        14.0               mocan t. suzana-iuliana   CLUJ
# 10645        17.0                      coroian i. ligia   CLUJ
# 10646        19.0                      giurgiu a. alina   ALBA
# 10647        28.0                        pataki a. vlad   CLUJ
# 10648         2.0                         nagy e. maria   CLUJ
# 10649         6.0                          pop f. ioana   CLUJ
# 10650        11.0                    dumitru i. lavinia   CLUJ
# 10651        12.0               muresan v. adela-ramona   CLUJ
# 10652        17.0                bogdan c. horia-andrei   CLUJ
# 10653        18.0                        rus v. liliana   CLUJ
# 10654        19.0                  calugar v. ana-maria   CLUJ
# 10655        24.0                 persa f. roxana maria   CLUJ
# 10656        26.0                       todea d. daniel   CLUJ
# 10657         1.0                       agratini o. ada   CLUJ
# 10658         2.0               crisan a. radu-cristian   CLUJ
# 10659         4.0                   trofin i. vlad-ioan   CLUJ
# 10660         7.0                          dan p. paula   CLUJ
# 10661        13.0             oprea v. adriana-gabriela   CLUJ
# 10662        17.0  marincean a. daniela-augusta-mihaela   CLUJ
# 10663        20.0                      cernea i. irimie   CLUJ
# 10664        22.0                     pintilie c. laura   CLUJ
# 10665        24.0          aruncutean d. domnita-stanca   CLUJ
#
#                                                  scoala media la admitere  \
# 0                            SC.CU CLS.I-VIII PIETROASA              9.32
# 1                  SC.CU CLS.I-VIII "N.POPOVICIU" BEIUS              9.12
# 2                             SC.CU CLS.I-VIII CALUGARI              8.71
# 3                              SC.CU CLS.I-VIII CARASAU              8.36
# 4                     LICEUL PEDAGOGIC "N.BOLCAS" BEIUS              8.31
# 5                              SC.CU CLS.I-VIII REMETEA               8.1
# 6                         SC.CU CLS.I-VIII HUTA VOIVOZI              8.08
# 7                              SC.CU CLS.I-VIII POMEZEU              8.04
# 8                            SC.CU CLS.I-VIII PIETROASA              8.03
# 9                            SC.CU CLS.I-VIII PIETROASA              8.01
# 10                            SC.CU CLS.I-VIII CURATELE               7.9
# 11                            SC.CU CLS.I-VIII CURATELE              7.73
# 12                            SC.CU CLS.I-VIII BUNTESTI              7.65
# 13              SC.CU CLS.I-VIII VIOREL HORJ DRAGANESTI               7.6
# 14                            SC.CU CLS.I-VIII CURATELE              7.59
# 15                              SC.CU CLS.I-VIII IOANIS              7.56
# 16                            SC.CU CLS.I-VIII CURATELE              7.52
# 17                            SC.CU CLS.I-VIII RABAGANI              7.52
# 18                           SC.CU CLS.I-VIII PIETROASA              7.46
# 19                             SC.CU CLS.I-VIII CARASAU              7.46
# 20                           SC.CU CLS.I-VIII BUDUREASA              7.45
# 21                             SC.CU CLS.I-VIII POMEZEU              7.42
# 22                            SC.CU CLS.I-VIII BUNTESTI              7.37
# 23                 SC.CU CLS.I-VIII DUMBRAVITA DE CODRU              7.35
# 24                            SC.CU CLS.I-VIII DOBRESTI              7.29
# 25                        LIC.TEORETIC "L.BLAGA" ORADEA              7.88
# 26                     SC.CU CLS.I-VIII "O.GOGA" ORADEA              7.85
# 27                     SC.CU CLS.I-VIII "O.GOGA" ORADEA              7.84
# 28                     SC.CU CLS.I-VIII "O.GOGA" ORADEA              7.81
# 29                    SC.CU CLS.I-VIII HUSASAU DE TINCA               7.8
# ...                                                 ...               ...
# 10636  SCOALA CU CLASELE I-VIII "TEODOR MURASANU" TURDA                10
# 10637      SCOALA CU CLASELE I-VIII "AVRAM IANCU" TURDA              9.92
# 10638      SCOALA CU CLASELE I-VIII "AVRAM IANCU" TURDA              9.78
# 10639  SCOALA CU CLASELE I-VIII "TEODOR MURASANU" TURDA              9.76
# 10640    SCOALA CU CLASELE I-VIII "ANDREI SAGUNA" TURDA              9.61
# 10641    SCOALA CU CLASELE I-VIII "ANDREI SAGUNA" TURDA              9.41
# 10642  SCOALA CU CLASELE I-VIII "TEODOR MURASANU" TURDA              9.31
# 10643          COLEGIUL NATIONAL "MIHAI VITEAZUL" TURDA              9.25
# 10644    SCOALA CU CLASELE I-VIII "ANDREI SAGUNA" TURDA              9.14
# 10645                 SCOALA CU CLASELE I-VIII CALARASI              8.96
# 10646                   SCOALA CU CLASELE I-VIII OCOLIS              8.67
# 10647      SCOALA CU CLASELE I-VIII "AVRAM IANCU" TURDA              7.13
# 10648       SCOALA CU CLASELE I-VIII "IOAN OPRIS" TURDA              9.81
# 10649       SCOALA CU CLASELE I-VIII "IOAN OPRIS" TURDA              9.67
# 10650       SCOALA CU CLASELE I-VIII "IOAN OPRIS" TURDA              9.64
# 10651    SCOALA CU CLASELE I-VIII "ANDREI SAGUNA" TURDA              9.61
# 10652  SCOALA CU CLASELE I-VIII "TEODOR MURASANU" TURDA               9.5
# 10653    SCOALA CU CLASELE I-VIII "ANDREI SAGUNA" TURDA              9.48
# 10654    SCOALA CU CLASELE I-VIII "ANDREI SAGUNA" TURDA              9.47
# 10655   SCOALA CU CLASELE I-VIII "GEORGE BARITIU" TURDA              9.34
# 10656       SCOALA CU CLASELE I-VIII "IOAN OPRIS" TURDA               9.3
# 10657                                        SCOALA ELF              9.72
# 10658          COLEGIUL NATIONAL "MIHAI VITEAZUL" TURDA              9.68
# 10659    SCOALA CU CLASELE I-VIII "ANDREI SAGUNA" TURDA              9.51
# 10660          COLEGIUL NATIONAL "MIHAI VITEAZUL" TURDA              9.37
# 10661    SCOALA CU CLASELE I-VIII "ANDREI SAGUNA" TURDA              9.14
# 10662    SCOALA CU CLASELE I-VIII "ANDREI SAGUNA" TURDA              9.03
# 10663             SCOALA CU CLASELE I-VIII MOLDOVENESTI              8.98
# 10664      SCOALA CU CLASELE I-VIII "AVRAM IANCU" TURDA              8.89
# 10665    SCOALA CU CLASELE I-VIII "ANDREI SAGUNA" TURDA              8.83
#
#       media teze nationale  media de absolvire   nota la limba romana  \
# 0                      9.1                9.54                   8.17
# 1                     8.63                9.62                   8.30
# 2                      7.9                9.52                   7.62
# 3                     8.21                8.51                   7.30
# 4                     7.73                8.89                   6.40
# 5                      7.3                8.90                   5.35
# 6                      6.7                9.47                   5.05
# 7                     7.18                8.91                   6.50
# 8                     8.48                7.58                   7.20
# 9                     8.32                7.71                   7.70
# 10                    7.41                8.39                   6.55
# 11                       7                8.47                   5.05
# 12                    7.36                7.94                   7.07
# 13                    7.01                8.19                   4.50
# 14                    7.18                8.00                   5.85
# 15                     6.3                8.83                   6.55
# 16                    7.16                7.89                   6.00
# 17                    6.66                8.38                   5.42
# 18                    7.93                6.99                   6.40
# 19                    6.92                8.01                   5.55
# 20                    6.74                8.16                   5.52
# 21                    7.11                7.74                   6.35
# 22                    7.01                7.74                   6.05
# 23                    6.21                8.50                   4.80
# 24                     6.2                8.38                   6.60
# 25                    6.87                8.90                   6.72
# 26                    7.77                7.93                   7.90
# 27                    7.84                7.84                   7.50
# 28                    7.76                7.86                   5.90
# 29                     7.7                7.90                   6.17
# ...                    ...                 ...                    ...
# 10636                   10               10.00                  10.00
# 10637                 9.85               10.00                   9.55
# 10638                 9.58                9.99                   9.30
# 10639                 9.82                9.71                   9.80
# 10640                  9.3                9.92                   8.40
# 10641                  8.9                9.92                   7.55
# 10642                 8.91                9.71                   7.87
# 10643                  8.9                9.61                   7.92
# 10644                 8.64                9.64                   8.15
# 10645                 8.19                9.74                   6.97
# 10646                 7.67                9.68                   6.62
# 10647                  6.1                8.17                   4.02
# 10648                  9.7                9.93                   9.35
# 10649                 9.39                9.95                   8.95
# 10650                 9.45                9.84                   9.10
# 10651                 9.28                9.94                   8.75
# 10652                 9.33                9.68                   8.35
# 10653                 9.14                9.82                   8.82
# 10654                 9.07                9.87                   8.75
# 10655                 8.93                9.75                   8.50
# 10656                 8.86                9.74                   9.15
# 10657                 9.56                9.89                   9.45
# 10658                  9.5                9.87                   9.10
# 10659                  9.2                9.83                   8.02
# 10660                 9.19                9.56                   9.00
# 10661                 8.52                9.76                   7.12
# 10662                 8.26                9.80                   7.20
# 10663                 8.29                9.68                   8.15
# 10664                 8.55                9.24                   8.35
# 10665                 8.16                9.50                   8.45
#
#        nota la matematica  optional8  ... disciplina profil nota  \
# 0                    9.45  Geografie  ...                   3.30
# 1                    8.00  Geografie  ...                   1.55
# 2                    6.97  Geografie  ...                   2.80
# 3                    7.95  Geografie  ...                   3.85
# 4                    8.72    Istorie  ...                   3.65
# 5                    7.67  Geografie  ...                   5.60
# 6                    6.90  Geografie  ...                   4.20
# 7                    7.07  Geografie  ...                   3.70
# 8                    8.97  Geografie  ...                   6.50
# 9                    7.77  Geografie  ...                   6.90
# 10                   6.62  Geografie  ...                   1.60
# 11                   6.87  Geografie  ...                   1.30
# 12                   7.12    Istorie  ...                   1.40
# 13                   8.05  Geografie  ...                   2.25
# 14                   7.15  Geografie  ...                   5.00
# 15                   5.95  Geografie  ...                   1.00
# 16                   7.20  Geografie  ...                   4.05
# 17                   6.27  Geografie  ...                   1.25
# 18                   8.37  Geografie  ...                   1.10
# 19                   7.65  Geografie  ...                   2.80
# 20                   6.05  Geografie  ...                   1.00
# 21                   7.37  Geografie  ...                   1.50
# 22                   7.10  Geografie  ...                   1.00
# 23                   6.15  Geografie  ...                   5.30
# 24                   5.87    Istorie  ...                   2.05
# 25                   5.35  Geografie  ...                   6.60
# 26                   6.27  Geografie  ...                   4.25
# 27                   7.60  Geografie  ...                   5.00
# 28                   7.92  Geografie  ...                   5.80
# 29                   7.45  Geografie  ...                   5.00
# ...                   ...        ...  ...                    ...
# 10636               10.00    Istorie  ...                   9.80
# 10637               10.00  Geografie  ...                   8.85
# 10638                9.70  Geografie  ...                   9.45
# 10639               10.00  Geografie  ...                   9.45
# 10640                9.50  Geografie  ...                   8.65
# 10641                9.17  Geografie  ...                   8.05
# 10642                9.27  Geografie  ...                   9.75
# 10643                9.35  Geografie  ...                   8.35
# 10644                8.20  Geografie  ...                   5.05
# 10645                8.70  Geografie  ...                   8.90
# 10646                7.47  geografie  ...                   6.50
# 10647                6.35    Istorie  ...                   5.70
# 10648                9.77    Istorie  ...                   8.90
# 10649                9.42    Istorie  ...                   9.15
# 10650                9.30  Geografie  ...                   8.70
# 10651                9.10  Geografie  ...                   8.20
# 10652                9.65  Geografie  ...                   8.65
# 10653                8.60  Geografie  ...                   7.60
# 10654                8.52  Geografie  ...                   8.15
# 10655                9.42  Geografie  ...                   7.30
# 10656                8.02    Istorie  ...                   8.50
# 10657                9.25    Istorie  ...                   9.80
# 10658                9.40    Istorie  ...                  10.00
# 10659                9.60  Geografie  ...                   9.50
# 10660                9.07    Istorie  ...                  10.00
# 10661                8.65  Geografie  ...                  10.00
# 10662                7.60  Geografie  ...                  10.00
# 10663                7.82    Istorie  ...                   9.60
# 10664                8.50  Geografie  ...                   6.50
# 10665                6.55  Geografie  ...                  10.00
#
#       disciplina profil contestatie disciplina profil final  \
# 0                               NaN                     3.3
# 1                               NaN                    1.55
# 2                              2.30                     2.3
# 3                              4.20                    3.85
# 4                              3.40                    3.65
# 5                               NaN                     5.6
# 6                              3.50                     3.5
# 7                               NaN                     3.7
# 8                               NaN                     6.5
# 9                               NaN                     6.9
# 10                              NaN                     1.6
# 11                              NaN                     1.3
# 12                              NaN                     1.4
# 13                              NaN                    2.25
# 14                             5.00                       5
# 15                              NaN                       1
# 16                             4.20                    4.05
# 17                              NaN                    1.25
# 18                              NaN                     1.1
# 19                              NaN                     2.8
# 20                              NaN                       1
# 21                              NaN                     1.5
# 22                              NaN                       1
# 23                              NaN                     5.3
# 24                              NaN                    2.05
# 25                              NaN                     6.6
# 26                             5.00                       5
# 27                              NaN                       5
# 28                              NaN                     5.8
# 29                              NaN                       5
# ...                             ...                     ...
# 10636                           NaN                     9.8
# 10637                           NaN                    8.85
# 10638                           NaN                    9.45
# 10639                           NaN                    9.45
# 10640                           NaN                    8.65
# 10641                          8.05                    8.05
# 10642                           NaN                    9.75
# 10643                           NaN                    8.35
# 10644                           NaN                    5.05
# 10645                           NaN                     8.9
# 10646                           NaN                     6.5
# 10647                           NaN                     5.7
# 10648                           NaN                     8.9
# 10649                           NaN                    9.15
# 10650                           NaN                     8.7
# 10651                           NaN                     8.2
# 10652                           NaN                    8.65
# 10653                           NaN                     7.6
# 10654                           NaN                    8.15
# 10655                           NaN                     7.3
# 10656                           NaN                     8.5
# 10657                           NaN                     9.8
# 10658                           NaN                      10
# 10659                           NaN                     9.5
# 10660                           NaN                      10
# 10661                           NaN                      10
# 10662                           NaN                      10
# 10663                           NaN                     9.6
# 10664                           NaN                     6.5
# 10665                           NaN                      10
#
#                                                 optional optional nota  \
# 0      Anatomie si fiziologie umana, genetica si ecol...          6.60
# 1      Anatomie si fiziologie umana, genetica si ecol...          7.55
# 2      Anatomie si fiziologie umana, genetica si ecol...          6.70
# 3      Anatomie si fiziologie umana, genetica si ecol...          6.30
# 4      Anatomie si fiziologie umana, genetica si ecol...          8.60
# 5      Anatomie si fiziologie umana, genetica si ecol...          6.85
# 6      Anatomie si fiziologie umana, genetica si ecol...          6.70
# 7                                              Geografie          7.00
# 8      Anatomie si fiziologie umana, genetica si ecol...          5.00
# 9      Anatomie si fiziologie umana, genetica si ecol...          6.80
# 10     Anatomie si fiziologie umana, genetica si ecol...          6.40
# 11     Anatomie si fiziologie umana, genetica si ecol...          6.45
# 12     Anatomie si fiziologie umana, genetica si ecol...          5.00
# 13     Anatomie si fiziologie umana, genetica si ecol...          5.00
# 14     Anatomie si fiziologie umana, genetica si ecol...          6.35
# 15     Anatomie si fiziologie umana, genetica si ecol...          5.80
# 16     Anatomie si fiziologie umana, genetica si ecol...          7.15
# 17     Anatomie si fiziologie umana, genetica si ecol...          7.60
# 18     Anatomie si fiziologie umana, genetica si ecol...          6.00
# 19     Anatomie si fiziologie umana, genetica si ecol...          5.00
# 20     Anatomie si fiziologie umana, genetica si ecol...          5.00
# 21     Anatomie si fiziologie umana, genetica si ecol...          5.60
# 22     Anatomie si fiziologie umana, genetica si ecol...          6.30
# 23     Anatomie si fiziologie umana, genetica si ecol...          5.25
# 24     Anatomie si fiziologie umana, genetica si ecol...          6.25
# 25                                             Geografie          9.20
# 26                                             Geografie          8.90
# 27                                             Geografie          7.10
# 28                                             Geografie          5.85
# 29                                             Geografie          5.60
# ...                                                  ...           ...
# 10636                               Informatica T1 C/C++          8.85
# 10637                               Informatica T1 C/C++          8.70
# 10638                               Informatica T1 C/C++          7.50
# 10639                               Informatica T1 C/C++          8.20
# 10640                               Informatica T1 C/C++          9.05
# 10641                               Informatica T1 C/C++          6.10
# 10642                               Informatica T1 C/C++          9.65
# 10643                               Informatica T1 C/C++          7.40
# 10644  Anatomie si fiziologie umana, genetica si ecol...          6.45
# 10645                                          Geografie          7.90
# 10646  Anatomie si fiziologie umana, genetica si ecol...          8.10
# 10647                    Biologie vegetala si animala T1          6.75
# 10648  Anatomie si fiziologie umana, genetica si ecol...          9.90
# 10649                        Chimie organica T1 Nivel II          9.00
# 10650                      Chimie anorganica T2 Nivel II          9.90
# 10651  Anatomie si fiziologie umana, genetica si ecol...          9.60
# 10652                        Chimie organica T1 Nivel II          8.80
# 10653  Anatomie si fiziologie umana, genetica si ecol...          9.00
# 10654  Anatomie si fiziologie umana, genetica si ecol...          9.60
# 10655  Anatomie si fiziologie umana, genetica si ecol...          9.15
# 10656  Anatomie si fiziologie umana, genetica si ecol...          9.40
# 10657                                         Sociologie          9.10
# 10658                                         Sociologie         10.00
# 10659                                         Sociologie          9.50
# 10660                                         Sociologie          9.50
# 10661                              Logica si argumentare          9.80
# 10662                                          Geografie          9.05
# 10663                                          Filosofie          9.00
# 10664                                             Fizica          5.45
# 10665                              Logica si argumentare         10.00
#
#       optional contestatie optional final competente digitale media  \
# 0                      NaN            6.6             Avansat  5.07
# 1                      NaN           7.55               Mediu   5.6
# 2                      NaN            6.7               Mediu   5.4
# 3                      NaN            6.3               Mediu  5.05
# 4                      NaN            8.6             Avansat   6.4
# 5                      NaN           6.85             Avansat  5.42
# 6                      NaN            6.7             Avansat  5.07
# 7                      NaN              7        Experimentat  5.63
# 8                      NaN              5               Mediu   6.2
# 9                      NaN            6.8               Mediu  6.77
# 10                     NaN            6.4             Avansat  4.33
# 11                     NaN           6.45               Mediu  4.48
# 12                     NaN              5               Mediu  3.45
# 13                     NaN              5           Incepator  4.92
# 14                     NaN           6.35             Avansat  5.45
# 15                     NaN            5.8             Avansat  3.93
# 16                     NaN           7.15               Mediu   5.8
# 17                     NaN            7.6               Mediu  4.65
# 18                     NaN              6               Mediu  3.17
# 19                     NaN              5           Incepator   4.6
# 20                     NaN              5               Mediu  3.67
# 21                     NaN            5.6               Mediu  3.45
# 22                     NaN            6.3               Mediu   4.1
# 23                     NaN           5.25               Mediu  4.78
# 24                     NaN           6.25           Incepator  4.93
# 25                     NaN            9.2             Avansat  7.85
# 26                     NaN            8.9             Avansat  6.78
# 27                     NaN            7.1             Avansat  6.53
# 28                     NaN           5.85             Avansat  5.55
# 29                     NaN            5.6               Mediu   4.8
# ...                    ...            ...                 ...   ...
# 10636                  8.5           8.85        Experimentat  9.35
# 10637                  NaN            8.7        Experimentat  8.33
# 10638                  NaN            7.5        Experimentat  8.53
# 10639                  7.8            8.2        Experimentat  8.55
# 10640                  8.6           9.05        Experimentat  8.07
# 10641                  6.0            6.1        Experimentat  7.92
# 10642                  NaN           9.65        Experimentat   9.1
# 10643                  NaN            7.4        Experimentat  8.28
# 10644                  6.3           6.45             Avansat  6.12
# 10645                  NaN            7.9             Avansat  7.65
# 10646                  NaN            8.1               Mediu  6.53
# 10647                  NaN           6.75             Avansat  5.85
# 10648                  NaN            9.9        Experimentat  9.07
# 10649                  NaN              9        Experimentat   8.9
# 10650                  NaN            9.9        Experimentat  9.45
# 10651                  NaN            9.6        Experimentat  8.88
# 10652                  NaN            8.8        Experimentat  7.72
# 10653                  NaN              9        Experimentat  7.53
# 10654                  NaN            9.6        Experimentat  8.32
# 10655                  NaN           9.15        Experimentat  6.65
# 10656                  NaN            9.4        Experimentat  8.63
# 10657                  NaN            9.1        Experimentat  9.47
# 10658                  NaN             10        Experimentat  9.33
# 10659                  NaN            9.5             Avansat   9.2
# 10660                  NaN            9.5        Experimentat  9.57
# 10661                  NaN            9.8        Experimentat  9.55
# 10662                  NaN           9.05        Experimentat  8.87
# 10663                  NaN              9        Experimentat  7.88
# 10664                  NaN           5.45           Incepator  6.35
# 10665                  NaN             10        Experimentat   9.8
#
#       rezultatul final
# 0              Respins
# 1              Respins
# 2              Respins
# 3              Respins
# 4              Respins
# 5              Respins
# 6              Respins
# 7              Respins
# 8               Reusit
# 9               Reusit
# 10             Respins
# 11             Respins
# 12             Respins
# 13             Respins
# 14             Respins
# 15             Respins
# 16             Respins
# 17             Respins
# 18             Respins
# 19             Respins
# 20             Respins
# 21             Respins
# 22             Respins
# 23             Respins
# 24             Respins
# 25              Reusit
# 26              Reusit
# 27              Reusit
# 28             Respins
# 29             Respins
# ...                ...
# 10636           Reusit
# 10637           Reusit
# 10638           Reusit
# 10639           Reusit
# 10640           Reusit
# 10641           Reusit
# 10642           Reusit
# 10643           Reusit
# 10644           Reusit
# 10645           Reusit
# 10646           Reusit
# 10647          Respins
# 10648           Reusit
# 10649           Reusit
# 10650           Reusit
# 10651           Reusit
# 10652           Reusit
# 10653           Reusit
# 10654           Reusit
# 10655          Respins
# 10656           Reusit
# 10657           Reusit
# 10658           Reusit
# 10659           Reusit
# 10660           Reusit
# 10661           Reusit
# 10662           Reusit
# 10663           Reusit
# 10664           Reusit
# 10665           Reusit
#
# [10666 rows x 42 columns]

# %%
s1.to_csv("note.csv", index=False)

# %%
df2.to_csv("note.csv", index=False)

# %%
any(s1['nume'].duplicated())
# Out:
# True

# %%
counts = s1.groupby('nume').size()
ss2 = pd.DataFrame(counts, columns = ['size2'])
ss2 = ss2[ss2.size2>1]
ss2.head()
# Out:
#                    size2
# nume
# fabian j. noemi        2
# ivan d. mihaela        3
# nagy s. ioan           2
# popa r. alexandru      2
# popa t. cristina       2

# %%
s1.keys()
# Out:
# Index([u'Unnamed: 0', u'nume', u'Unnamed: 2', u'SCOALA', u'Media\nla admitere',
#        u'Media\nteze nationale', u'Media de\nabsolvire',
#        u'\nNota la\nlimba romana', u'Nota la\nmatematica', u'OPTIONAL8',
#        u'OPTIONAL8 NOTA', u'Limba materna8', u'Limba materna8 nota',
#        u'pozitia in ierarhie pe judet', u'pozitia in ierarhie pe tara',
#        u'unitatea de invatamant', u'judetul', u'promotie anterioara',
#        u'forma invatamant', u'specializare', u'romana oral', u'romana nota',
#        u'romana contestatie', u'romana final', u'limba materna',
#        u'materna oral', u'materna nota', u'materna contestatie',
#        u'materna final', u'limba moderna', u'limba moderna \r\nnota',
#        u'disciplina profil', u'disciplina profil \r\nnota',
#        u'disciplina profil contestatie', u'disciplina profil final',
#        u'optional', u'optional\r\nnota', u'optional contestatie',
#        u'optional final', u'competente digitale', u'media',
#        u'rezultatul final'],
#       dtype='object')

# %%
s1['Limba și literatura română\r\nScris']
# Out:
# 0      7.10
# 1      7.75
# 2      7.60
# 3      9.50
# 4      9.00
# 5      7.10
# 6      5.00
# 7      7.35
# 8      5.00
# 9      3.05
# 10     5.80
# 11     5.10
# 12     5.00
# 13     9.00
# 14     4.20
# 15     3.90
# 16     4.45
# 17     5.00
# 18     0.00
# 19     5.00
# 20     4.10
# 21     8.10
# 22     9.00
# 23     7.60
# 24     9.00
# 25     9.20
# 26     6.85
# 27     9.30
# 28     8.30
# 29     6.00
#        ...
# 156    9.40
# 157    7.45
# 158    8.65
# 159    8.00
# 160    6.50
# 161    9.60
# 162    6.90
# 163    9.10
# 164    6.25
# 165    6.15
# 166    5.00
# 167    4.60
# 168    8.40
# 169    8.55
# 170    9.75
# 171    8.85
# 172    5.70
# 173    6.00
# 174    7.20
# 175    3.50
# 176    8.00
# 177    9.50
# 178    8.00
# 179    8.60
# 180    9.20
# 181    8.85
# 182    7.55
# 183    5.05
# 184    7.10
# 185    9.40
# Name: Limba și literatura română\r\nScris, Length: 186, dtype: float64

# %%
dat = s1[['Media de\nabsolvire','Nota la\nmatematica','\nNota la\nlimba romana','Unitatea de învățământ', 'Limba și literatura română\r\nScris']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-8043dc78e0b5> in <module>()
# ----> 1 dat = s1[['Media de\nabsolvire','Nota la\nmatematica','\nNota la\nlimba romana','Unitatea de învățământ', 'Limba și literatura română\r\nScris']]
#
# c:\python27\lib\site-packages\pandas\core\frame.pyc in __getitem__(self, key)
#    2932                 key = list(key)
#    2933             indexer = self.loc._convert_to_indexer(key, axis=1,
# -> 2934                                                    raise_missing=True)
#    2935
#    2936         # take() does not accept boolean indexers
#
# c:\python27\lib\site-packages\pandas\core\indexing.pyc in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1352                 kwargs = {'raise_missing': True if is_setter else
#    1353                           raise_missing}
# -> 1354                 return self._get_listlike_indexer(obj, axis, **kwargs)[1]
#    1355         else:
#    1356             try:
#
# c:\python27\lib\site-packages\pandas\core\indexing.pyc in _get_listlike_indexer(self, key, axis, raise_missing)
#    1159         self._validate_read_indexer(keyarr, indexer,
#    1160                                     o._get_axis_number(axis),
# -> 1161                                     raise_missing=raise_missing)
#    1162         return keyarr, indexer
#    1163
#
# c:\python27\lib\site-packages\pandas\core\indexing.pyc in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1250             if not(self.name == 'loc' and not raise_missing):
#    1251                 not_found = list(set(key) - set(ax))
# -> 1252                 raise KeyError("{} not in index".format(not_found))
#    1253
#    1254             # we skip the warning on Categorical/Interval
#
# KeyError: "['Media de\\nabsolvire', 'Nota la\\nmatematica', '\\nNota la\\nlimba romana'] not in index"

# %%
dat.shape

# %%
dat.info()

# %%
dat.head()

# %%
dat['Unitatea de învățământ']

# %%
le = LabelEncoder()
dat['Unitatea de învățământ'] = le.fit_transform(dat['Unitatea de învățământ'])

# %%
dat['Unitatea de învățământ']

# %%
X = dat.loc[:, dat.columns != 'Limba și literatura română\r\nScris']

# %%
X.shape

# %%
y = s1['Limba și literatura română\r\nScris'].values.reshape(-1,1)

# %%
y

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
regressor = LinearRegression()  
regressor.fit(X_train, y_train) #training the algorithm

# %%
#To retrieve the intercept:
print(regressor.intercept_)

#For retrieving the slope:
print(regressor.coef_)

# %%
y_pred = regressor.predict(X_test)

# %%
res = pd.DataFrame({'Actual': y_test.flatten(), 'Predicted': y_pred.flatten()})

# %%
res

# %%
print('Mean Squared Error:', mean_squared_error(y_test, y_pred))

# %%
accuracy_score(y_test, y_pred)
