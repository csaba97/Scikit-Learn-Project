# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.metrics import mean_squared_error
from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv('note.csv')
df.isna().sum()
# Out:
# nume                                 0
# judet8                               0
# scoala                               0
# media la admitere                    0
# media teze nationale                 0
# media de absolvire                   0
# nota la limba romana                 0
# nota la matematica                   0
# optional8                            0
# optional8 nota                       0
# limba materna8                       0
# limba materna8 nota                  0
# pozitia in ierarhie pe judet         0
# pozitia in ierarhie pe tara          0
# unitatea de invatamant               0
# judetul                              0
# promotie anterioara                  0
# forma invatamant                     0
# specializare                         0
# romana oral                         38
# romana nota                          0
# romana contestatie                9129
# romana final                         0
# limba materna                     9293
# ...

# %%
df.isna().sum()
# Out:
# nume                                 0
# judet8                               0
# scoala                               0
# media la admitere                    0
# media teze nationale                 0
# media de absolvire                   0
# nota la limba romana                 0
# nota la matematica                   0
# optional8                            0
# optional8 nota                       0
# limba materna8                       0
# limba materna8 nota                  0
# pozitia in ierarhie pe judet         0
# pozitia in ierarhie pe tara          0
# unitatea de invatamant               0
# judetul                              0
# promotie anterioara                  0
# forma invatamant                     0
# specializare                         0
# romana oral                          0
# romana nota                          0
# romana contestatie                9009
# romana final                         0
# limba materna                     9174
# ...

# %%
df = df.replace(0, pd.np.nan).dropna(axis=0, how='any', subset=['media la admitere'])

# %%
df[df.columns[3]] = df[df.columns[3]].apply(pd.to_numeric, errors='coerce').fillna(0).astype(float)
df = df[df['media la admitere'] != 0]

df['optional8 nota'] = df['optional8 nota'].astype(float)

# %%
df = df.dropna(axis=0, how='any', subset=['competente digitale'])
df = df.dropna(axis=0, how='any', subset=['romana oral'])

# %%
df[3490:]
# Out:
#                                        nume   judet  \
# 3490                        vajda j. renata   MURES
# 3491                         vass g. monika   MURES
# 3492                         vass f. monika   MURES
# 3493                      gergely s. jozsef   MURES
# 3494                         csibi a. endre   MURES
# 3495                         nagy l. lorand   MURES
# 3496          butiulca d. dorina-paraschiva   MURES
# 3497                        balazs e. endre   MURES
# 3498               boitos i. cristina-maria   MURES
# 3499                        dinga d. roxana   MURES
# 3500               vinteler i. iacob-mihail   MURES
# 3501                titi v. andreea-viorica   MURES
# 3502                  moldovan i. ana-maria  BRASOV
# 3503                   roman m. laura-diana   MURES
# 3504                     munteanu c. ionela   MURES
# 3505                       romonti c. ioana   MURES
# 3506                  pantea v. elena-maria   MURES
# ...

# %%
df.shape
# Out:
# (10172, 41)

# %%
df.keys()
# Out:
# Index([u'nume', u'judet', u'scoala', u'media la admitere',
#        u'media teze nationale', u'media de absolvire',
#        u' nota la limba romana', u'nota la matematica', u'optional8',
#        u'optional8 nota', u'limba materna8', u'limba materna8 nota ',
#        u'pozitia in ierarhie pe judet', u'pozitia in ierarhie pe tara',
#        u'unitatea de invatamant', u'judetul', u'promotie anterioara',
#        u'forma invatamant', u'specializare', u'romana oral', u'romana nota',
#        u'romana contestatie', u'romana final', u'limba materna',
#        u'materna oral', u'materna nota', u'materna contestatie',
#        u'materna final', u'limba moderna', u'limba moderna nota',
#        u'disciplina profil', u'disciplina profil nota',
#        u'disciplina profil contestatie', u'disciplina profil final',
#        u'optional', u'optional nota', u'optional contestatie',
#        u'optional final', u'competente digitale', u'media',
#        u'rezultatul final'],
#       dtype='object')

# %%
df.apply(lambda x: pd.to_numeric(df['media la admitere'], errors='coerce')).dropna()
# Out:
#         nume  judet8  scoala  media la admitere  media teze nationale  \
# 0       9.32    9.32    9.32               9.32                  9.32
# 1       9.12    9.12    9.12               9.12                  9.12
# 2       8.71    8.71    8.71               8.71                  8.71
# 3       8.36    8.36    8.36               8.36                  8.36
# 4       8.31    8.31    8.31               8.31                  8.31
# 5       8.10    8.10    8.10               8.10                  8.10
# 6       8.08    8.08    8.08               8.08                  8.08
# 7       8.04    8.04    8.04               8.04                  8.04
# 8       8.03    8.03    8.03               8.03                  8.03
# 9       8.01    8.01    8.01               8.01                  8.01
# 10      7.90    7.90    7.90               7.90                  7.90
# 11      7.73    7.73    7.73               7.73                  7.73
# ...

# %%
df[df.columns[3]] = df[df.columns[3]].apply(pd.to_numeric, errors='coerce').fillna(0).astype(float).dropna()

# %%
df.columns[11]
# Out:
# 'limba materna8 nota'

# %%
df[df.columns[3]] = df[df.columns[3]].apply(pd.to_numeric, errors='coerce').fillna(0).astype(float).dropna()
#df[df.columns[11]] = df[df.columns[11]].apply(pd.to_numeric, errors='coerce').fillna(0).astype(float).dropna()

df = df.replace(0, pd.np.nan).dropna(axis=0, how='any', subset=['media la admitere'])
#df = df.replace(0, pd.np.nan).dropna(axis=0, how='any', subset=['limba materna8 nota'])

df['optional8 nota'] = df['optional8 nota'].astype(float)
df[''].fillna(0, inplace=True)
#df['limba materna8 nota'] = df['limba materna8 nota'].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10112 entries, 0 to 10236
# Data columns (total 41 columns):
# nume                             10112 non-null object
# judet8                           10112 non-null object
# scoala                           10112 non-null object
# media la admitere                10112 non-null float64
# media teze nationale             10112 non-null float64
# media de absolvire               10112 non-null float64
# nota la limba romana             10112 non-null float64
# nota la matematica               10112 non-null float64
# optional8                        10112 non-null object
# optional8 nota                   10112 non-null float64
# limba materna8                   10112 non-null object
# limba materna8 nota              10112 non-null object
# pozitia in ierarhie pe judet     10112 non-null int64
# pozitia in ierarhie pe tara      10112 non-null int64
# unitatea de invatamant           10112 non-null object
# ...

# %%
df['media la admitere'] = pd.to_numeric(df['media la admitere'], errors='coerce').dropna()

# %%
df['media la admitere'] = df['media la admitere'].astype(float)

# %%
df.keys()
# Out:
# Index([u'nume', u'judet8', u'scoala', u'media la admitere',
#        u'media teze nationale', u'media de absolvire', u'nota la limba romana',
#        u'nota la matematica', u'optional8', u'optional8 nota',
#        u'limba materna8', u'limba materna8 nota',
#        u'pozitia in ierarhie pe judet', u'pozitia in ierarhie pe tara',
#        u'unitatea de invatamant', u'judetul', u'promotie anterioara',
#        u'forma invatamant', u'specializare', u'romana oral', u'romana nota',
#        u'romana contestatie', u'romana final', u'limba materna',
#        u'materna oral', u'materna nota', u'materna contestatie',
#        u'materna final', u'limba moderna', u'limba moderna nota',
#        u'disciplina profil', u'disciplina profil nota',
#        u'disciplina profil contestatie', u'disciplina profil final',
#        u'optional', u'optional nota', u'optional contestatie',
#        u'optional final', u'competente digitale', u'media',
#        u'rezultatul final'],
#       dtype='object')

# %%
df.columns = df.columns.str.strip()

# %%
df.keys()
# Out:
# Index([u'nume', u'judet8', u'scoala', u'media la admitere',
#        u'media teze nationale', u'media de absolvire', u'nota la limba romana',
#        u'nota la matematica', u'optional8', u'optional8 nota',
#        u'limba materna8', u'limba materna8 nota',
#        u'pozitia in ierarhie pe judet', u'pozitia in ierarhie pe tara',
#        u'unitatea de invatamant', u'judetul', u'promotie anterioara',
#        u'forma invatamant', u'specializare', u'romana oral', u'romana nota',
#        u'romana contestatie', u'romana final', u'limba materna',
#        u'materna oral', u'materna nota', u'materna contestatie',
#        u'materna final', u'limba moderna', u'limba moderna nota',
#        u'disciplina profil', u'disciplina profil nota',
#        u'disciplina profil contestatie', u'disciplina profil final',
#        u'optional', u'optional nota', u'optional contestatie',
#        u'optional final', u'competente digitale', u'media',
#        u'rezultatul final'],
#       dtype='object')

# %%
sum(df['nume'].duplicated())
# Out:
# 232

# %%
df.drop_duplicates(subset='nume', keep=False, inplace=True)

# %%
df.shape
# Out:
# (10172, 41)

# %%
sum(df['nume'].duplicated())
# Out:
# 0

# %%
df.isna().sum()
# Out:
# nume                                 0
# judet8                               0
# scoala                               0
# media la admitere                    0
# media teze nationale                 0
# media de absolvire                   0
# nota la limba romana                 0
# nota la matematica                   0
# optional8                            0
# optional8 nota                       0
# limba materna8                       0
# limba materna8 nota                  0
# pozitia in ierarhie pe judet         0
# pozitia in ierarhie pe tara          0
# unitatea de invatamant               0
# judetul                              0
# promotie anterioara                  0
# forma invatamant                     0
# specializare                         0
# romana oral                         38
# romana nota                          0
# romana contestatie                9069
# romana final                         0
# limba materna                     9228
# ...

# %%
df.dropna(subset=['media la admitere'], how='all', inplace = True)

# %%
df.isna().sum()
# Out:
# nume                                 0
# judet                                0
# scoala                               0
# media la admitere                    0
# media teze nationale                 0
# media de absolvire                   0
#  nota la limba romana                0
# nota la matematica                   0
# optional8                            0
# optional8 nota                       0
# limba materna8                       0
# limba materna8 nota                  0
# pozitia in ierarhie pe judet         0
# pozitia in ierarhie pe tara          0
# unitatea de invatamant               0
# judetul                              0
# promotie anterioara                  0
# forma invatamant                     0
# specializare                         0
# romana oral                         38
# romana nota                          0
# romana contestatie                9129
# romana final                         0
# limba materna                     9293
# ...

# %%
df.shape
# Out:
# (1030, 41)

# %%
df.to_csv("note.csv", index=False)

# %%
df
# Out:
#                                        nume judet8  \
# 0                          cireap p. florin  BIHOR
# 1                     gabor i. ionut darius  BIHOR
# 2                   bogan s. sebastian doru  BIHOR
# 3                     apati m. mihai bogdan  BIHOR
# 4                  filip g. flaviu georgian  BIHOR
# 5                      dan m. ovidiu vasile  BIHOR
# 6                            korch s. iozef  BIHOR
# 7                    hora i. cristian ionut  BIHOR
# 8                   jude a. corneliu daniel  BIHOR
# 9                    groza u. raul cristian  BIHOR
# 10                petroian v. florin adrian  BIHOR
# 11                   bogdan i. remus daniel  BIHOR
# 12                  bonchis a. costel tudor  BIHOR
# 13                  lungu p. nicusor marius  BIHOR
# 14                gligor l. florin cristian  BIHOR
# 15                   popa m. mihaela alicia  BIHOR
# 16              breanc t. marius constantin  BIHOR
# ...
