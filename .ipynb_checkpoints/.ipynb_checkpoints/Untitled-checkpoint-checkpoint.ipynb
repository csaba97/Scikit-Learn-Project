# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('evaluare.csv')

# %%
df2 = pd.read_csv('12-07.csv')
# Out:
# c:\python27\lib\site-packages\IPython\core\interactiveshell.py:2714: DtypeWarning: Columns (2,16,22,26,28) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#    Unnamed: 0                           Nume Unnamed: 2  \
# 0         NaN           SZABO E. CSILLA REKA       CLUJ
# 1         NaN      KEGYES I. KRISZTINA TIMEA       CLUJ
# 2         NaN  FULOP BALOGH A. BEATRIX EMOKE       CLUJ
# 3         NaN                DEAK I. NORBERT       CLUJ
# 4         NaN         BALOGH E. IMOLA RENATA       CLUJ
#
#                                          SCOALA  Media\nla admitere  \
# 0            SCOALA CU CLASELE I-VIII NR. 1 DEJ                9.87
# 1  LICEUL TEORETIC "BATHORY ISTVAN" CLUJ-NAPOCA                9.69
# 2  LICEUL TEORETIC "BATHORY ISTVAN" CLUJ-NAPOCA                9.66
# 3  LICEUL TEORETIC "BATHORY ISTVAN" CLUJ-NAPOCA                9.60
# 4  LICEUL TEORETIC "BATHORY ISTVAN" CLUJ-NAPOCA                9.53
#
#    Media\nteze nationale  Media de\nabsolvire  \nNota la\nlimba romana  \
# 0                   9.75                10.00                     9.67
# 1                   9.45                 9.93                     8.97
# 2                   9.35                 9.97                     8.42
# 3                   9.24                 9.97                     7.85
# 4                   9.45                 9.62                     8.87
#
#    Nota la\nmatematica  OPTIONAL8  OPTIONAL8 NOTA Limba materna8  \
# 0                 9.35  Geografie            10.0       Maghiara
# 1                 9.95    Istorie             9.8       Maghiara
# 2                 9.90    Istorie             9.5       Maghiara
# 3                10.00    Istorie            10.0       Maghiara
# 4                 9.57    Istorie             9.8       Maghiara
#
#   Limba materna8 nota
# 0                  10
# 1                9.07
# 2                9.57
# 3                9.12
# 4                9.55

# %%
df2.head()
# Out:
#                         Nume  Pozi?ia �n ierarhie pe jude?  \
# 0       A. Anei G. Ana Maria                          1111
# 1  A-Anei I. Flaviu-Octavian                          1062
# 2  Aanegroae S. C. Ana-Maria                            57
# 3         Aanei G. Alexandru                           754
# 4         Aanei I. Ana Maria                          2626
#
#   Pozi?ia �n ierarhie pe ?ar?  \
# 0                       37997
# 1                       40643
# 2                        2206
# 3                       24312
# 4                       93520
#
#                               Unitatea de �nv???m�nt Jude?ul  \
# 0    Colegiul National "Stefan Cel Mare" Tirgu Neamt      NT
# 1  Liceul De Arte Plastice "Hans Mattis-Teutsch" ...      BV
# 2       Colegiul National "Petru Rares" Piatra Neamt      NT
# 3              Colegiul National "Ferdinand I" Bacau      BC
# 4   Colegiul Tehnic "Gheorghe Cartianu" Piatra Neamt      NT
#
#   Promotie anterioar? Forma �nv???m�nt  \
# 0                  Nu               Zi
# 1                  Nu               Zi
# 2                  Nu               Zi
# 3                  Nu               Zi
# 4                  Nu               Zi
#
#                                         Specializare  \
# 0                             Matematica-Informatica
# 1             Arhitectura, arte ambientale si design
# 2                             Matematica-Informatica
# 3                             Matematica-Informatica
# 4  Tehnician desenator pentru constructii si inst...
#
#   Limba ?i literatura rom�n?\r\nCompeten?e  \
# 0                             Experimentat
# 1                                  Avansat
# 2                             Experimentat
# 3                             Experimentat
# 4                             Experimentat
#
#    Limba ?i literatura rom�n?\r\nScris  ...  \
# 0                                 8.85  ...
# 1                                 6.30  ...
# 2                                 8.40  ...
# 3                                 8.60  ...
# 4                                 5.60  ...
#
#    Disciplina obligatorie a profilului\r\nNota  \
# 0                                         5.60
# 1                                         7.15
# 2                                         9.70
# 3                                         8.00
# 4                                         3.20
#
#    Disciplina obligatorie a profilului\r\nContesta?ie  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                               3.15
#
#   Disciplina obligatorie a profilului\r\nNota final?  \
# 0                                                5.6
# 1                                               7.15
# 2                                                9.7
# 3                                                  8
# 4                                                3.2
#
#                                Disciplina la alegere  \
# 0  Anatomie si fiziologie umana, genetica si ecol...
# 1                                          Geografie
# 2                                             Fizica
# 3                               Informatica T1 C/C++
# 4                    Biologie vegetala si animala T1
#
#    Disciplina la alegere\r\nNota  Disciplina la alegere\r\nContesta?ie  \
# 0                           8.85                                   NaN
# 1                           9.50                                   NaN
# 2                           9.55                                   NaN
# 3                           8.50                                   NaN
# 4                           7.70                                   NaN
#
#   Disciplina la alegere\r\nNota final? Competen?e digitale Media  \
# 0                                 8.85             Avansat  7.77
# 1                                  9.5        Experimentat  7.65
# 2                                 9.55        Experimentat   9.6
# 3                                  8.5        Experimentat  8.37
# 4                                  7.7        Experimentat   5.5
#
#   Rezultatul final
# 0           Reu?it
# 1           Reu?it
# 2           Reu?it
# 3           Reu?it
# 4          Respins
#
# [5 rows x 30 columns]

# %%
s1 = pd.merge(df, df2, how='inner', on=['Nume'])

# %%
s1.head()
# Out:
# Empty DataFrame
# Columns: [Nume, Unnamed: 1, Unnamed: 2, Unnamed: 3, Unnamed: 4, Unnamed: 5, Unnamed: 6, Unnamed: 7, Unnamed: 8, Unnamed: 9, Unnamed: 10, Unnamed: 11, Pozi?ia �n ierarhie pe jude?, Pozi?ia �n ierarhie pe ?ar?, Unitatea de �nv???m�nt, Jude?ul, Promotie anterioar?, Forma �nv???m�nt, Specializare, Limba ?i literatura rom�n?
# Competen?e, Limba ?i literatura rom�n?
# Scris, Limba ?i literatura rom�n?
# Contesta?ie, Limba ?i literatura rom�n?
# Nota final?, Limba ?i literatura matern?, Limba ?i literatura matern?
# Competen?e, Limba ?i literatura matern?
# Scris, Limba ?i literatura matern?
# Contesta?ie, Limba ?i literatura matern?
# Nota final?, Limba modern? studiat?, Limba modern? studiat?
# Nota, Disciplina obligatorie a profilului, Disciplina obligatorie a profilului
# Nota, Disciplina obligatorie a profilului
# Contesta?ie, Disciplina obligatorie a profilului
# Nota final?, Disciplina la alegere, Disciplina la alegere
# Nota, Disciplina la alegere
# Contesta?ie, Disciplina la alegere
# Nota final?, Competen?e digitale, Media, Rezultatul final]
# Index: []
#
# [0 rows x 41 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 12 columns):
# Nume           30 non-null object
# Unnamed: 1     30 non-null object
# Unnamed: 2     30 non-null object
# Unnamed: 3     30 non-null float64
# Unnamed: 4     30 non-null float64
# Unnamed: 5     30 non-null float64
# Unnamed: 6     30 non-null float64
# Unnamed: 7     30 non-null float64
# Unnamed: 8     30 non-null object
# Unnamed: 9     30 non-null float64
# Unnamed: 10    30 non-null object
# Unnamed: 11    30 non-null float64
# dtypes: float64(7), object(5)
# memory usage: 2.3+ KB

# %%
df.dtypes
# Out:
# Nume            object
# Unnamed: 1      object
# Unnamed: 2      object
# Unnamed: 3     float64
# Unnamed: 4     float64
# Unnamed: 5     float64
# Unnamed: 6     float64
# Unnamed: 7     float64
# Unnamed: 8      object
# Unnamed: 9     float64
# Unnamed: 10     object
# Unnamed: 11    float64
# dtype: object

# %%
df2.dtypes
# Out:
# Nume                                                   object
# Poziția în ierarhie pe județ                            int64
# Poziția în ierarhie pe țară                             int64
# Unitatea de învățământ                                 object
# Județul                                                object
# Promotie anterioară                                    object
# Forma învățământ                                       object
# Specializare                                           object
# Limba și literatura română\r\nCompetențe               object
# Limba și literatura română\r\nScris                   float64
# Limba și literatura română\r\nContestație             float64
# Limba și literatura română\r\nNota finală             float64
# Limba și literatura maternă                            object
# Limba și literatura maternă\r\nCompetențe              object
# Limba și literatura maternă\r\nScris                  float64
# Limba și literatura maternă\r\nContestație            float64
# Limba și literatura maternă\r\nNota finală            float64
# Limba modernă studiată                                 object
# Limba modernă studiată\r\nNota                         object
# Disciplina obligatorie a profilului                    object
# Disciplina obligatorie a profilului\r\nNota           float64
# Disciplina obligatorie a profilului\r\nContestație    float64
# Disciplina obligatorie a profilului\r\nNota finală    float64
# Disciplina la alegere                                  object
# Disciplina la alegere\r\nNota                         float64
# Disciplina la alegere\r\nContestație                  float64
# Disciplina la alegere\r\nNota finală                  float64
# Competențe digitale                                    object
# Media                                                 float64
# Rezultatul final                                       object
# dtype: object

# %%
df2.Nume = df2.Nume.astype(str)

# %%
df2.Nume
# Out:
# 0                         A. Anei G. Ana Maria
# 1                    A-Anei I. Flaviu-Octavian
# 2                    Aanegroae S. C. Ana-Maria
# 3                           Aanei G. Alexandru
# 4                           Aanei I. Ana Maria
# 5                             Aanei I. Andreea
# 6                      Aanei M. Cristina-Elena
# 7                        Aanei D. Marian-Danut
# 8                      Aanei N. Simona-Daniela
# 9                   Aanei-Murariu A. Alexandra
# 10                        Aanicai V. Elisabeta
# 11                          Aanicai C. Mihaela
# 12                 Aanicai V. Monique Adrianne
# 13                Aanitei E. Gabriela-Marinela
# 14                          Aanitei D. M. Ioan
# 15                Aarmeniei A. Ionut-Alexandru
# 16                         Ababei C. Alexandru
# 17                           Ababei D. Andreea
# 18                  Ababei R. Andreea-Loredana
# 19                      Ababei J. Andrei Ionut
# 20                     Ababei C. Andrei Razvan
# 21                            Ababei T. Aurora
# 22                       Ababei G. Bogdan-Gelu
# 23                           Ababei S. Claudia
# 24                  Ababei C. Constantin-Cezar
# 25                       Ababei . Cosmin Mihai
# 26                   Ababei I. Daniela-Andreea
# 27                    Ababei L. Dumitrita-Neli
# 28                   Ababei C. A. Elena-Roxana
# 29                    Ababei M. Eusebiu Lucian
#                           ...
# 200157              Zuzu F. R. Isabela Daniela
# 200158                    Zuzu I. Mihai Marius
# 200159                     Zvanca I. Alexandra
# 200160                    Zvancea G. Alexandra
# 200161                Zvanciuc N. Oana-Teodora
# 200162               Zvarici D. Andreea-Roxana
# 200163               Zvarici I. N. Andrei Ioan
# 200164             Zvarici F. Giorgiana-Tereza
# 200165                   Zvenca T. Claudiu-Ion
# 200166                     Zveta V. Paul-Sabin
# 200167                 Zvinca C. Bogdan Robert
# 200168                 Zvinca F. Daniel-Costel
# 200169                Zvinca C. Narcis-Claudiu
# 200170                        Zvinca G. Roxana
# 200171               Zvinca C. Roxana-Emanuela
# 200172             Zvinca F. Stelian-Alexandru
# 200173                 Zvincu C. Anca-Cristina
# 200174                          Zvincu . Elena
# 200175              Zvincu F. Stefan Cristinel
# 200176    Zvolentschi L. M. Florentina-Mihaela
# 200177                         Zvonca I. Petru
# 200178                        Zvorici M. Alisa
# 200179                   Zvoristeanu A. Andrei
# 200180               Zvoristeanu N. Oana-Elena
# 200181              Zvoristeanu P. Petru-Sorin
# 200182                  Zvunca I. Ionut-Adrian
# 200183                         Zvunca I. Maria
# 200184                         Zvunca I. Maria
# 200185                    Zvunka I. Ioan Dorel
# 200186                   Zyma G. M. Anne-Maria
# Name: Nume, Length: 200187, dtype: object

# %%
df.Nume = df.Nume.astype(str)

# %%
df.dtypes
# Out:
# Nume            object
# Unnamed: 1      object
# Unnamed: 2      object
# Unnamed: 3     float64
# Unnamed: 4     float64
# Unnamed: 5     float64
# Unnamed: 6     float64
# Unnamed: 7     float64
# Unnamed: 8      object
# Unnamed: 9     float64
# Unnamed: 10     object
# Unnamed: 11    float64
# dtype: object

# %%
df2.dtypes
# Out:
# Nume                                                   object
# Poziția în ierarhie pe județ                            int64
# Poziția în ierarhie pe țară                             int64
# Unitatea de învățământ                                 object
# Județul                                                object
# Promotie anterioară                                    object
# Forma învățământ                                       object
# Specializare                                           object
# Limba și literatura română\r\nCompetențe               object
# Limba și literatura română\r\nScris                   float64
# Limba și literatura română\r\nContestație             float64
# Limba și literatura română\r\nNota finală             float64
# Limba și literatura maternă                            object
# Limba și literatura maternă\r\nCompetențe              object
# Limba și literatura maternă\r\nScris                  float64
# Limba și literatura maternă\r\nContestație            float64
# Limba și literatura maternă\r\nNota finală            float64
# Limba modernă studiată                                 object
# Limba modernă studiată\r\nNota                         object
# Disciplina obligatorie a profilului                    object
# Disciplina obligatorie a profilului\r\nNota           float64
# Disciplina obligatorie a profilului\r\nContestație    float64
# Disciplina obligatorie a profilului\r\nNota finală    float64
# Disciplina la alegere                                  object
# Disciplina la alegere\r\nNota                         float64
# Disciplina la alegere\r\nContestație                  float64
# Disciplina la alegere\r\nNota finală                  float64
# Competențe digitale                                    object
# Media                                                 float64
# Rezultatul final                                       object
# dtype: object

# %%
s1 = pd.merge(df, df2, how='inner', on=['Nume'])

# %%
s1.head()
# Out:
# Empty DataFrame
# Columns: [Nume, Unnamed: 1, Unnamed: 2, Unnamed: 3, Unnamed: 4, Unnamed: 5, Unnamed: 6, Unnamed: 7, Unnamed: 8, Unnamed: 9, Unnamed: 10, Unnamed: 11, Pozi?ia �n ierarhie pe jude?, Pozi?ia �n ierarhie pe ?ar?, Unitatea de �nv???m�nt, Jude?ul, Promotie anterioar?, Forma �nv???m�nt, Specializare, Limba ?i literatura rom�n?
# Competen?e, Limba ?i literatura rom�n?
# Scris, Limba ?i literatura rom�n?
# Contesta?ie, Limba ?i literatura rom�n?
# Nota final?, Limba ?i literatura matern?, Limba ?i literatura matern?
# Competen?e, Limba ?i literatura matern?
# Scris, Limba ?i literatura matern?
# Contesta?ie, Limba ?i literatura matern?
# Nota final?, Limba modern? studiat?, Limba modern? studiat?
# Nota, Disciplina obligatorie a profilului, Disciplina obligatorie a profilului
# Nota, Disciplina obligatorie a profilului
# Contesta?ie, Disciplina obligatorie a profilului
# Nota final?, Disciplina la alegere, Disciplina la alegere
# Nota, Disciplina la alegere
# Contesta?ie, Disciplina la alegere
# Nota final?, Competen?e digitale, Media, Rezultatul final]
# Index: []
#
# [0 rows x 41 columns]

# %%
df.Nume = df.Nume.str.encode('utf-8')
df2.Nume = df2.Nume.str.encode('utf-8')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-70-fcf4c711f8d1> in <module>()
#       1 df.Nume = df.Nume.str.encode('utf-8')
# ----> 2 df2.Nume = df2.Nume.str.encode('utf-8')
#
# c:\python27\lib\site-packages\pandas\core\strings.pyc in encode(self, encoding, errors)
#    2655     @copy(str_encode)
#    2656     def encode(self, encoding, errors="strict"):
# -> 2657         result = str_encode(self._parent, encoding, errors)
#    2658         return self._wrap_result(result)
#    2659
#
# c:\python27\lib\site-packages\pandas\core\strings.pyc in str_encode(arr, encoding, errors)
#    1731         encoder = codecs.getencoder(encoding)
#    1732         f = lambda x: encoder(x, errors)[0]
# -> 1733     return _na_map(f, arr)
#    1734
#    1735
#
# c:\python27\lib\site-packages\pandas\core\strings.pyc in _na_map(f, arr, na_result, dtype)
#      57 def _na_map(f, arr, na_result=np.nan, dtype=object):
#      58     # should really _check_ for NA
# ---> 59     return _map(f, arr, na_mask=True, na_value=na_result, dtype=dtype)
#      60
#      61
#
# c:\python27\lib\site-packages\pandas\core\strings.pyc in _map(f, arr, na_mask, na_value, dtype)
#      72         try:
#      73             convert = not all(mask)
# ---> 74             result = lib.map_infer_mask(arr, f, mask.view(np.uint8), convert)
#      75         except (TypeError, AttributeError) as e:
#      76             # Reraise the exception if callable `f` got wrong number of args.
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer_mask()
#
# c:\python27\lib\site-packages\pandas\core\strings.pyc in <lambda>(x)
#    1727     if encoding in _cpython_optimized_encoders:
#    1728         # CPython optimized implementation
# -> 1729         f = lambda x: x.encode(encoding, errors)
#    1730     else:
#    1731         encoder = codecs.getencoder(encoding)
#
# UnicodeDecodeError: 'ascii' codec can't decode byte 0xa6 in position 7: ordinal not in range(128)

# %%
df.Nume = df.Nume.str.strip()
df2.Nume = df2.Nume.str.strip()

# %%
s1 = pd.merge(df, df2, how='inner', on=['Nume'])

# %%
s1.head()
# Out:
#                    Nume Unnamed: 1  \
# 0       deak i. norbert       CLUJ
# 1       kovacs p. kinga       CLUJ
# 2       kovacs p. kinga       CLUJ
# 3       kispal z. timea       CLUJ
# 4  debreczeni i. istvan       CLUJ
#
#                                      Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# 0  LICEUL TEORETIC "BATHORY ISTVAN" CLUJ-NAPOCA        9.60        9.24
# 1  LICEUL TEORETIC "BATHORY ISTVAN" CLUJ-NAPOCA        9.45        9.21
# 2  LICEUL TEORETIC "BATHORY ISTVAN" CLUJ-NAPOCA        9.45        9.21
# 3  LICEUL TEORETIC "BATHORY ISTVAN" CLUJ-NAPOCA        9.34        8.98
# 4  LICEUL TEORETIC "BATHORY ISTVAN" CLUJ-NAPOCA        9.07        8.56
#
#    Unnamed: 5  Unnamed: 6  Unnamed: 7 Unnamed: 8  Unnamed: 9  ...  \
# 0        9.97        7.85       10.00    Istorie       10.00  ...
# 1        9.69        7.90        9.55    Istorie        9.75  ...
# 2        9.69        7.90        9.55    Istorie        9.75  ...
# 3        9.70        8.35        9.57    Istorie        8.55  ...
# 4        9.58        7.37        8.95  Geografie        9.80  ...
#
#   Disciplina obligatorie a profilului\r\nNota  \
# 0                                       10.00
# 1                                        9.30
# 2                                        8.85
# 3                                        9.15
# 4                                        6.95
#
#    Disciplina obligatorie a profilului\r\nContesta?ie  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Disciplina obligatorie a profilului\r\nNota final?  \
# 0                                                 10
# 1                                                9.3
# 2                                               8.85
# 3                                               9.15
# 4                                               6.95
#
#                                Disciplina la alegere  \
# 0                              Informatica T1 Pascal
# 1  Anatomie si fiziologie umana, genetica si ecol...
# 2                                          Geografie
# 3                              Informatica T1 Pascal
# 4                       Chimie anorganica T2 Nivel I
#
#   Disciplina la alegere\r\nNota Disciplina la alegere\r\nContesta?ie  \
# 0                          9.85                                  NaN
# 1                         10.00                                  NaN
# 2                          8.35                                  NaN
# 3                          9.50                                  NaN
# 4                          9.00                                  NaN
#
#   Disciplina la alegere\r\nNota final? Competen?e digitale Media  \
# 0                                 9.85        Experimentat  9.03
# 1                                   10        Experimentat  8.96
# 2                                 8.35               Mediu  8.56
# 3                                  9.5        Experimentat   9.1
# 4                                    9             Avansat  8.51
#
#   Rezultatul final
# 0           Reu?it
# 1           Reu?it
# 2           Reu?it
# 3           Reu?it
# 4           Reu?it
#
# [5 rows x 41 columns]

# %%
df.Nume = df.Nume.str.lower()
df2.Nume = df2.Nume.str.lower()

# %%
df.head()
# Out:
#                             Nume Unnamed: 1  \
# 0           szabo e. csilla reka       CLUJ
# 1      kegyes i. krisztina timea       CLUJ
# 2  fulop balogh a. beatrix emoke       CLUJ
# 3                deak i. norbert       CLUJ
# 4         balogh e. imola renata       CLUJ
#
#                                      Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# 0            SCOALA CU CLASELE I-VIII NR. 1 DEJ        9.87        9.75
# 1  LICEUL TEORETIC "BATHORY ISTVAN" CLUJ-NAPOCA        9.69        9.45
# 2  LICEUL TEORETIC "BATHORY ISTVAN" CLUJ-NAPOCA        9.66        9.35
# 3  LICEUL TEORETIC "BATHORY ISTVAN" CLUJ-NAPOCA        9.60        9.24
# 4  LICEUL TEORETIC "BATHORY ISTVAN" CLUJ-NAPOCA        9.53        9.45
#
#    Unnamed: 5  Unnamed: 6  Unnamed: 7 Unnamed: 8  Unnamed: 9 Unnamed: 10  \
# 0       10.00        9.67        9.35  Geografie        10.0    Maghiara
# 1        9.93        8.97        9.95    Istorie         9.8    Maghiara
# 2        9.97        8.42        9.90    Istorie         9.5    Maghiara
# 3        9.97        7.85       10.00    Istorie        10.0    Maghiara
# 4        9.62        8.87        9.57    Istorie         9.8    Maghiara
#
#    Unnamed: 11
# 0        10.00
# 1         9.07
# 2         9.57
# 3         9.12
# 4         9.55
